# %% [markdown]
# # F20DV - LAB 4

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/state_crime.csv")
display(df.head(3))
# Out:
#      State  Year  Data.Population  Data.Rates.Property.All  \
# 0  Alabama  1960          3266740                   1035.4
# 1  Alabama  1961          3302000                    985.5
# 2  Alabama  1962          3358000                   1067.0
#
#    Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 0                         355.9                        592.1
# 1                         339.3                        569.4
# 2                         349.1                        634.5
#
#    Data.Rates.Property.Motor  Data.Rates.Violent.All  \
# 0                       87.3                   186.6
# 1                       76.8                   168.5
# 2                       83.4                   157.3
#
#    Data.Rates.Violent.Assault  Data.Rates.Violent.Murder  ...  \
# 0                       138.1                       12.4  ...
# 1                       128.9                       12.9  ...
# 2                       119.0                        9.4  ...
#
# ...

# %%
bool_series = df.duplicated()
display(bool_series)
print(bool_series[0])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3110    False
# 3111    False
# 3112    False
# 3113    False
# 3114    False
# Length: 3115, dtype: bool
# False

# %%
for i in range(3115):
    if(bool_series[i] == True):
        print(i)
        print(bool_series[i])

# %%
df.rename(columns={
    "State": "state", 
    "Year": "year", 
    "Data.Population": "population", 

    "Data.Rates.Property.All": "property_rates_all", 
    "Data.Rates.Property.Burglary": "rates_burglary", 
    "Data.Rates.Property.Larceny": "rates_larceny",
    "Data.Rates.Property.Motor": "rates_motor",

    "Data.Rates.Violent.All": "violent_rates_all",
    "Data.Rates.Violent.Assault": "rates_assault",
    "Data.Rates.Violent.Murder": "rates_murder",
    "Data.Rates.Violent.Rape": "rates_rape",
    "Data.Rates.Violent.Robbery": "rates_robbery",

    "Data.Totals.Property.All": "property_total_all",
    "Data.Totals.Property.Burglary": "total_burglary",
    "Data.Totals.Property.Larceny": "total_larceny",
    "Data.Totals.Property.Motor": "total_motor",

    "Data.Totals.Violent.All": "violent_total_all",
    "Data.Totals.Violent.Assault": "total_assault",
    "Data.Totals.Violent.Murder": "total_murder",
    "Data.Totals.Violent.Rape": "total_rape",
    "Data.Totals.Violent.Robbery": "total_robbery"
}, inplace = True)

display(df)
# Out:
#         state  year  population  property_rates_all  rates_burglary  \
# 0     Alabama  1960     3266740              1035.4           355.9
# 1     Alabama  1961     3302000               985.5           339.3
# 2     Alabama  1962     3358000              1067.0           349.1
# 3     Alabama  1963     3347000              1150.9           376.9
# 4     Alabama  1964     3407000              1358.7           466.6
# ...       ...   ...         ...                 ...             ...
# 3110  Wyoming  2015      586107               179.8          1902.6
# 3111  Wyoming  2016      585501              1957.3           302.5
# 3112  Wyoming  2017      579315              1830.4           275.0
# 3113  Wyoming  2018      577737              1785.1           264.0
# 3114  Wyoming  2019      578759              1571.1           241.2
#
#       rates_larceny  rates_motor  violent_rates_all  rates_assault  \
# 0             592.1         87.3              186.6          138.1
# ...

# %%
new_df = df[(df["state"] != "United States") & (df["year"] >= 1965)]
display(new_df)
new_df.to_csv("data/crimeUS.csv", index=False)
# Out:
#         state  year  population  property_rates_all  rates_burglary  \
# 5     Alabama  1965     3462000              1392.7           473.7
# 6     Alabama  1966     3517000              1528.0           527.5
# 7     Alabama  1967     3540000              1612.4           571.4
# 8     Alabama  1968     3566000              1766.6           628.2
# 9     Alabama  1969     3531000              1876.2           667.2
# ...       ...   ...         ...                 ...             ...
# 3110  Wyoming  2015      586107               179.8          1902.6
# 3111  Wyoming  2016      585501              1957.3           302.5
# 3112  Wyoming  2017      579315              1830.4           275.0
# 3113  Wyoming  2018      577737              1785.1           264.0
# 3114  Wyoming  2019      578759              1571.1           241.2
#
#       rates_larceny  rates_motor  violent_rates_all  rates_assault  \
# 5             812.1        106.9              199.8          149.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3115 entries, 0 to 3114
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               3115 non-null   object
#  1   year                3115 non-null   int64
#  2   population          3115 non-null   int64
#  3   property_rates_all  3115 non-null   float64
#  4   rates_burglary      3115 non-null   float64
#  5   rates_larceny       3115 non-null   float64
#  6   rates_motor         3115 non-null   float64
#  7   violent_rates_all   3115 non-null   float64
#  8   rates_assault       3115 non-null   float64
#  9   rates_murder        3115 non-null   float64
#  10  rates_rape          3115 non-null   float64
#  11  rates_robbery       3115 non-null   float64
#  12  property_total_all  3115 non-null   int64
#  13  total_burglary      3115 non-null   int64
#  14  total_larceny       3115 non-null   int64
# ...

# %%
finance_df = pd.read_csv("data/finance.csv")
display(finance_df.head(3))
# Out:
#      State  Year  Totals.Capital outlay  Totals.Revenue  Totals.Expenditure  \
# 0  ALABAMA  1992                 664748        10536166             9650515
# 1  ALABAMA  1993                 781952        11389335            10242374
# 2  ALABAMA  1994                 767100        11599362            10815221
#
#    Totals.General expenditure  Totals.General revenue  \
# 0                     8788293                 8910315
# 1                     9339796                 9688246
# 2                     9922352                10014415
#
#    Totals.Insurance trust  revenue  Totals.Intergovernmental  \
# 0                          1473217                   2737180
# 1                          1570768                   2965310
# 2                          1454982                   3077084
#
#    Totals.License tax  ...  \
# 0              395202  ...
# 1              377723  ...
# 2              386771  ...
#
#    Details.Welfare.Welfare Institution Total Expenditure  \
# ...

# %%
finance_df.rename(columns={
    "State": "state", 
    "Year": "year",

    "Totals.Capital outlay": "capital_outlay_total", 
    "Totals.Revenue": "revenue_total", 
    "Totals.Expenditure": "expenditure_total",
    "Totals.General expenditure": "general_expenditure_total",

    "Totals.General revenue": "general_revenue_total",
    "Totals.Insurance trust  revenue": "insurance_trust_revenue_total",
    "Totals.Intergovernmental": "intergovernmental_total",
    "Totals.License tax": "license_tax_total",
    "Totals.Selective sales tax": "selective_sales_tax_total",

    "Totals.Tax": "tax_total",
    "Details.Correction.Correction Total": "correction_total",
    "Details.Education.Education Total": "education_total",
    "Details.Financial Aid.Assistance and Subsidies": "assistance_subsidies",

    "Details.Financial Aid.Cash and Securities Total": "cash_securities_total",
    "Details.Health.Health Total Expenditure": "health_total_txpenditure",
    "Details.Intergovernmental.Intergovernmental Expenditure": "intergovernmental_expenditure",
    "Details.Intergovernmental.Intergovernmental to Combined and Unallocable": "intergovernmental_combined_unallocable",
    "Details.Natural Resources.Natural Resources Construction": "natural_resources_construction",
    "Details.Utilities.Utilities Current Operation": "utilities_current_operation",
    "Details.Welfare.Welfare Institution Total Expenditure": "welfare_institution_total_expenditure",
    "Details.Natural Resources.Parks.Parks Total Expenditure": "parks_total_expenditure",
    "Details.Transportation.Highways.Highways Total Expenditure": "highways_total_expenditure",
    "Totals. Debt at end of fiscal year": "debt_at_end_of_fiscal_year",
    "Details.Insurance benefits and repayments": "insurance_benefits_and_repayments",
    "Details.Interest on debt": "interest_on_debt",
    "Details.Interest on general debt": "interest_on_general_debt",
    "Details.Miscellaneous general revenue": "miscellaneous_general_revenue",
    "Details.Other taxes": "other_taxes",
    "Details.Police protection": "police_protection"
}, inplace = True)

display(finance_df)
# Out:
#         state  year  capital_outlay_total  revenue_total  expenditure_total  \
# 0     ALABAMA  1992                664748       10536166            9650515
# 1     ALABAMA  1993                781952       11389335           10242374
# 2     ALABAMA  1994                767100       11599362           10815221
# 3     ALABAMA  1995                808001       12279726           11541881
# 4     ALABAMA  1996                760751       12741148           12126587
# ...       ...   ...                   ...            ...                ...
# 1046  WYOMING  2015                467279        7983068            6089770
# 1047  WYOMING  2016                484691        6453279            6272333
# 1048  WYOMING  2017                475405        7000634            6445250
# 1049  WYOMING  2018                513325        7652548            6308802
# 1050  WYOMING  2019                518769        6131182            6159829
#
# ...

# %%
finance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051 entries, 0 to 1050
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   state                                   1051 non-null   object
#  1   year                                    1051 non-null   int64
#  2   capital_outlay_total                    1051 non-null   int64
#  3   revenue_total                           1051 non-null   int64
#  4   expenditure_total                       1051 non-null   int64
#  5   general_expenditure_total               1051 non-null   int64
#  6   general_revenue_total                   1051 non-null   int64
#  7   insurance_trust_revenue_total           1051 non-null   int64
#  8   intergovernmental_total                 1051 non-null   int64
#  9   license_tax_total                       1051 non-null   int64
# ...

# %%
finance_df.to_csv("data/financeUS.csv", index=False)
